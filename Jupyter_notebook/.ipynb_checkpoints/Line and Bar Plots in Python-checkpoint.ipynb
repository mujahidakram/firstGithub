# %% [markdown]
# ## Line Plots and Bar Plots in Python with Baba Aammar PhD

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set

iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set

iris=sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # How to add title to your graph

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set

iris=sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=iris)
plt.title("IRIS Sepal Length and Width Graph")
plt.show()

# %% [markdown]
# ## How to increase or decrease area of plot

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set

iris=sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=iris)
#area under consideration use xlim and ylim
plt.xlim(3)
plt.ylim(1)

plt.title("IRIS Sepal Length and Width Graph")
plt.show()

# %% [markdown]
# ## How to add styles to your plot
# ### types of styles in seaborn
# - whitegrid
# - darkgrid
# - white
# - dark
# - ticks

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set
sns.set_style("whitegrid")

iris=sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=iris)
plt.title("IRIS Sepal Length and Width Graph")
plt.show()

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set
sns.set_style("whitegrid")

iris=sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=iris)
plt.title("IRIS Sepal Length and Width Graph")
plt.show()

# %% [markdown]
# ### Bar Plots in Python

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set
sns.set_style("whitegrid")

iris=sns.load_dataset("iris")

sns.barplot(x="species", y="sepal_width", data=iris)
plt.title("IRIS Sepal Length and Width Graph")
plt.show()

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set
sns.set_style("whitegrid")

iris=sns.load_dataset("iris")

sns.barplot(x="species", y="sepal_width", data=iris, color="red")
plt.title("IRIS Sepal Length and Width Graph")
plt.show()

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set
sns.set_style("whitegrid")

titanic=sns.load_dataset("titanic")

sns.barplot(x="sex", y="alone", hue="who" , data=titanic )
plt.title("TITANIC Barplot")
plt.show()

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


#load Data Set
sns.set_style("whitegrid")

titanic=sns.load_dataset("titanic")

sns.barplot(x="sex", y="alone", hue="who" , data=titanic, order=["female", "male"], color="teal")
plt.title("TITANIC Barplot")
plt.show()

# %%
#Import Libraries
import seaborn as sns
import pandas as pd
from numpy import mean
import matplotlib.pyplot as plt


#load Data Set
sns.set_style("whitegrid")

titanic=sns.load_dataset("titanic")

sns.barplot(x="class", y="fare", hue="sex" , data=titanic, color="teal", ci=None, estimator=median)
plt.title("TITANIC Barplot")
plt.show()
